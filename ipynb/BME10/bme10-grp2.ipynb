# %% [markdown]
# # Student part
#
# - Visualize any data from `data/` or example data from [`scikit-learn`](http://scikit-learn.org/stable/datasets/index.html) or [`scikit-image`](http://scikit-image.org/docs/dev/auto_examples/).
# - Do your best and DO NOT copy from your friends.
# - 3 Things to do: Load, Process and Visualize.
# - Processing step doesn't have to be complex, just simple function like sum and average are ok. But feel free to show your advance skill as much as you want would be best.
# - Your advance knowledge would be a plus in this class.

# %% [markdown]
# ## Group Members
#
# Firstname Lastname (Nickname) Student id.
#
# 1. Kittiphat Harnpradit (Bogie) 5913266
# 2. Nathachetpong Chinwichit (Nut) 5913275
# 3. Kanyarat Boonkham (Aoff) 5913430
# 4. Samach Juntavet (Pruang) 5913441

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os import pardir, path
# %matplotlib inline

# to be able to render thai font
# on linux system, uses 'Loma'
# on windows system, uses 'Angsana New' or 'TH SarabunPSK'
plt.rcParams["font.family"] = ["Loma", 'Angsana New', 'TH SarabunPSK']

# %%
# define function to return full path of data from data filename
# There are 3 naming styles used here. However, it is recommented to use meaningful name.
# Shorthand name should only be used when prototyping or personal code.

# These functions do the same thing, return the same result.

# shorthand namimg
def dp(dataFileName):
    '''
    This function is used to get full data path (dp) from data file name.
    '''
    return path.join(pardir ,pardir, 'data', dataFileName)

# camelCase naming
def getDataPath(dataFileName):
    '''
    This function is used to get full data path from data file name.
    '''
    return path.join(pardir, 'data', dataFileName)

# delimiter separated naming
def get_data_path(dataFileName):
    '''
    This function is used to get full data path from data file name.
    '''
    return path.join(pardir, 'data', dataFileName)

# %%
# here we get data from https://data.go.th/
# some of them are encoded with 'utf-8' some of them are 'cp874'
# you will know when you first load data, if it cannot be read change encoding

df = pd.read_csv(dp('Pokemon.csv'), encoding='utf-8')
# df = pd.read_csv(dp('travel_amount_2558.csv'))

# %%
df
#แสดงตาราง
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
to_plot_df = df.groupby(['Type 1']).mean()

to_plot_df
#แสดงตารางที่จำแนกตาม Type 1
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
pt = to_plot_df['Total'].plot(kind='bar', figsize=(15,5), fontsize=18)
plt.xlabel(pt.get_xlabel(), fontsize=22)
plt.ylabel('Average of Total Ability', fontsize=22)
plt.title('Average of Total Ability by Type 1', fontsize=30)
#แสดงกราฟ Average of Total Ability by Type 1
# Out:
# Text(0.5,1,'Average of Total Ability by Type 1')

# %%
sorting = to_plot_df.sort_values(by=['Total'])
#เรียงลำดับ Average of Total Ability by Type 1

# %%
pt = sorting['Total'].plot(kind='bar', figsize=(15,5), fontsize=18)
plt.xlabel(pt.get_xlabel(), fontsize=22)
plt.ylabel('Average of Total Ability', fontsize=22)
plt.title('Average of Total Ability by Type 1', fontsize=30)
#แสดงกราฟที่เรียงลำดับ Average of Total Ability by Type 1 จากต่ำไปสูง
# Out:
# Text(0.5,1,'Average of Total Ability by Type 1')

# %%
dragon = df.loc[df['Type 1'] == 'Dragon']
#แสดงกราฟเฉพาะ Type Dragon

# %%
dragon.sort_values(by=['Total'], ascending=False)
#แสดงตารางที่เรียงลำดับ Total Ability ของ Type Dragon จากสูงไปต่ำ
# Out:
#        #                     Name  Type 1    Type 2  Total   HP  Attack  \
# 426  384    RayquazaMega Rayquaza  Dragon    Flying    780  105     180
# 420  381        LatiosMega Latios  Dragon   Psychic    700   80     130
# 418  380        LatiasMega Latias  Dragon   Psychic    700   80     100
# 711  646       KyuremBlack Kyurem  Dragon       Ice    700  125     170
# 712  646       KyuremWhite Kyurem  Dragon       Ice    700  125     120
# 494  445    GarchompMega Garchomp  Dragon    Ground    700  108     170
# 409  373  SalamenceMega Salamence  Dragon    Flying    700   95     145
# 706  643                 Reshiram  Dragon      Fire    680  100     120
# 425  384                 Rayquaza  Dragon    Flying    680  105     150
# 707  644                   Zekrom  Dragon  Electric    680  100     150
# 710  646                   Kyurem  Dragon       Ice    660  125     130
# 417  380                   Latias  Dragon   Psychic    600   80      80
# ...

# %%
dragon.sort_values(by=['Total'], ascending=False)[0:5]
#แสดง Average of Total Ability 5 ลำดับสูงสุดของ Type Dragon
# Out:
#        #                   Name  Type 1   Type 2  Total   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza  Dragon   Flying    780  105     180      100
# 420  381      LatiosMega Latios  Dragon  Psychic    700   80     130      100
# 418  380      LatiasMega Latias  Dragon  Psychic    700   80     100      120
# 711  646     KyuremBlack Kyurem  Dragon      Ice    700  125     170      100
# 712  646     KyuremWhite Kyurem  Dragon      Ice    700  125     120       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 426      180      100    115           3       True
# 420      160      120    110           3       True
# 418      140      150    110           3       True
# 711      120       90     95           5       True
# 712      170      100     95           5       True
