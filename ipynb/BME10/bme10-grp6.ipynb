# %% [markdown]
# # Student part
#
# - Visualize any data from `data/` or example data from [`scikit-learn`](http://scikit-learn.org/stable/datasets/index.html) or [`scikit-image`](http://scikit-image.org/docs/dev/auto_examples/).
# - Do your best and DO NOT copy from your friends.
# - 3 Things to do: Load, Process and Visualize.
# - Processing step doesn't have to be complex, just simple function like sum and average are ok. But feel free to show your advance skill as much as you want would be best.
# - Your advance knowledge would be a plus in this class.

# %% [markdown]
# ## Group Members
#
# Firstname Lastname (Nickname) Student id.
#
# 1. Chayanont jongmekwamsuk (Tube) 5913270
# 2. Preranut laothanasin (Gut) 5913279
# 3. Thanutporn  ariyapanitchwong (Nut) 5913434

# %%
# %ls "../../data"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3E8B-91BF
#
#  Directory of C:\Users\AIM-BENZ\gitrepo\labclass\data
#
# 03/23/2018  04:36 PM    <DIR>          .
# 03/23/2018  04:36 PM    <DIR>          ..
# 03/23/2018  03:40 PM            11,999 kitchen_debt_41_58.csv
# 08/29/2016  06:01 AM            44,028 Pokemon.csv
# 02/23/2018  09:15 AM             7,345 PS_PT_015_TH_ALL.CSV
# 03/23/2018  04:25 PM    <DIR>          set-archive_EOD
# 09/28/2017  01:09 AM         5,698,602 tmdb_5000_movies.csv
# 02/21/2018  06:38 PM           560,761 traffic_amount_2558.csv
# 03/23/2018  11:19 AM            12,302 travel_amount_2558.csv
#                6 File(s)      6,335,037 bytes
#                3 Dir(s)  32,185,159,680 bytes free

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os import pardir, path
# %matplotlib inline

# to be able to render thai font
# on linux system, uses 'Loma'
# on windows system, uses 'Angsana New' or 'TH SarabunPSK'
plt.rcParams["font.family"] = ["Loma", 'Angsana New', 'TH SarabunPSK']

# %%
# define function to return full path of data from data filename
# There are 3 naming styles used here. However, it is recommented to use meaningful name.
# Shorthand name should only be used when prototyping or personal code.

# These functions do the same thing, return the same result.

# shorthand namimg
def dp(dataFileName):
    '''
    This function is used to get full data path (dp) from data file name.
    '''
    return path.join(pardir,pardir, 'data', dataFileName)

# camelCase naming
def getDataPath(dataFileName):
    '''
    This function is used to get full data path from data file name.
    '''
    return path.join(pardir, 'data', dataFileName)

# delimiter separated naming
def get_data_path(dataFileName):
    '''
    This function is used to get full data path from data file name.
    '''
    return path.join(pardir, 'data', dataFileName)

# %%
# here we get data from https://data.go.th/
# some of them are encoded with 'utf-8' some of them are 'cp874'
# you will know when you first load data, if it cannot be read change encoding

df = pd.read_csv(dp('Pokemon.csv'), encoding='utf-8')
#loading dataframe

# %%
df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
# groupby, find average and Maximum. 
# .groupby() is a function of class DataFrame, so we can directly call it after function.

to_plot_df = df.groupby(['Type 1', 'Generation']).agg({'Total': ['mean'], 'Speed': ['max']})

to_plot_df
# Out:
#                           Total Speed
#                            mean   max
# Type 1   Generation
# Bug      1           366.428571   145
#          2           428.750000    95
#          3           318.833333   160
#          4           373.100000    95
#          5           416.111111   145
#          6           274.666667    89
# Dark     2           465.000000   115
#          3           421.666667   115
#          4           538.333333   125
#          5           417.923077   106
#          6           483.333333    99
# Dragon   1           440.000000    80
#          3           596.666667   120
#          4           502.500000   102
#          5           575.000000    97
#          6           488.000000    95
# Electric 1           444.444444   140
#          2           415.714286   115
#          3           431.000000   135
#          4           472.416667    95
#          5           446.875000   116
#          6           400.333333   109
# ...

# %%
# then we plot desired column
pt = to_plot_df['Total'].plot(kind='bar', figsize=(18,8), fontsize=14)

plt.xlabel(pt.get_xlabel(), fontsize=22)
plt.ylabel('Average Total', fontsize=22)
plt.title('Number of pokemon group by type 1 and generations', fontsize=36)
# Out:
# Text(0.5,1,'Number of pokemon group by type 1 and generations')

# %%
# look at list of columns name below and select what to plot
for i, item in enumerate(df.columns.unique().tolist()):
    print(i, item)
# Out:
# 0 #
# 1 Name
# 2 Type 1
# 3 Type 2
# 4 Total
# 5 HP
# 6 Attack
# 7 Defense
# 8 Sp. Atk
# 9 Sp. Def
# 10 Speed
# 11 Generation
# 12 Legendary

# %%
#Sorting values of total mean.
to_plot_df.sort_values([('Total', 'mean')], ascending=True)
# Out:
#                           Total Speed
#                            mean   max
# Type 1   Generation
# Bug      6           274.666667    89
#          3           318.833333   160
# Fairy    2           323.600000    45
# Fighting 2           332.500000    70
# Ice      2           333.750000    75
# Normal   6           352.500000   102
# Bug      1           366.428571   145
# Normal   3           369.888889   125
# Bug      4           373.100000    95
# Ground   1           374.375000   120
# Grass    2           377.000000   110
# Fighting 3           382.200000   100
# Poison   1           383.500000    90
# Flying   6           390.000000   123
# Ghost    5           390.200000    80
# Normal   2           390.933333   100
#          1           397.416667   121
# Electric 6           400.333333   109
# Poison   5           401.500000    75
# Fairy    1           403.000000    60
# Poison   4           404.666667    95
#          6           407.000000    44
# ...

# %%
# then we plot desired column
ptt = to_plot_df.sort_values([('Total', 'mean')], ascending=True).plot(kind='bar', figsize=(18,8), fontsize=14)

plt.xlabel(pt.get_xlabel(), fontsize=22)
plt.ylabel('Average Total', fontsize=22)
plt.title('Number of pokemon group by type1 and generation', fontsize=36)
# Out:
# Text(0.5,1,'Number of pokemon group by type1 and generation')

# %%
# groupby and count
# .groupby() is a function of class DataFrame, so we can directly call it after function.
# .count() is a function of groupby object, so we can also call it after getting groupby object.

count = df.groupby(['Type 1']).count()

count
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
#sorting values as above In[32]
pltCount = count.sort_values([('#')], ascending=True)
pltCount
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Flying      4     4       2      4    4       4        4        4        4
# Fairy      17    17       2     17   17      17       17       17       17
# Ice        24    24      11     24   24      24       24       24       24
# Fighting   27    27       7     27   27      27       27       27       27
# Steel      27    27      22     27   27      27       27       27       27
# Poison     28    28      13     28   28      28       28       28       28
# Dark       31    31      21     31   31      31       31       31       31
# Ghost      32    32      22     32   32      32       32       32       32
# Dragon     32    32      21     32   32      32       32       32       32
# Ground     32    32      19     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# ...

# %%
# then we plot desired column
pt =pltCount['#'].plot(kind='bar', figsize=(18,8), fontsize=14)

plt.xlabel(pt.get_xlabel(), fontsize=22)
plt.ylabel('Average Total', fontsize=22)
plt.title('Number of pokemon group by type1', fontsize=36)
# Out:
# Text(0.5,1,'Number of pokemon group by type1')
